# %% [markdown]
# <a href="https://colab.research.google.com/github/Arseniy-Polyakov/speech_technologies_course/blob/main/HW6_ASR_with_noise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# В ходе работы сравним качество распознавания речи в тихом месте и с шумами, а также сравним как показатели cer и wer отличаются в данном случае

# %% [markdown]
# Также как и в домашней работе номер 5 будем использовать модель "Шопот" и Nexara, и в том числе параллельно сравним как две эти модели распознают речь с шумом и без него

# %% [markdown]
# Установим библиотеки для подсчета cer, wer

# %%
# !pip install jiwer
# Out:
# Collecting jiwer
#   Downloading jiwer-4.0.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from jiwer) (8.3.0)
# Collecting rapidfuzz>=3.9.7 (from jiwer)
#   Downloading rapidfuzz-3.14.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Downloading jiwer-4.0.0-py3-none-any.whl (23 kB)
# Downloading rapidfuzz-3.14.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 36.7 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-4.0.0 rapidfuzz-3.14.1

# %% [markdown]
# Импортируем модули для работы с данными и статистиками

# %%
import pandas as pd
from jiwer import cer, wer

# %%
target_text = """На данном этапе в Data Science NLP является одним из самых популярных направлений, наряду с компьютерным зрением и рекомендательными системами. И сегодня можно рассказать немножко о методах, которые включаются NLP. Что такое в принципе NLP? NLP это Natural Language Processing, это автоматическая обработка текста с помощью компьютерных либо математических методов.
Ну и самое основное, что это методы, которые помогают понять значение языка и сделать определенные манипуляции с текстом либо с языком. Ну и от этого выходят основные задачи. Мы можем с помощью данных методов классифицировать тексты, то есть определять их на разные группы. Допустим, в контексте сентимент-анализа, когда нам нужно определить, положительные ли это тексты, либо негативные.
Также можно выделить эмоции текстов, допустим, грусть, радость, печаль, удивление и так далее. Либо разбить тексты по топикам или, как их называют в диалоговых системах, интенты для построения флоу диалога и ведения его, или в целом построения архитектуры FAQ в чат-ботах или голосовых ассистентах.
Кластеризация — это задача определения групп без меток, то есть у нас есть неразмеченные данные, и задача кластеризации будет относиться к задаче unsupervised learning, то есть это обучение без учителя, так как мы имеем дело с неразмеченными данными в отличие от классификации обучение с учителем.
Также есть классические задачи машинного перевода, и на самом деле в NLP они являются одними из самых, наверное, старых, потому что применялись еще в прошлом веке в контексте электротехнического автоматического перевода, либо там французско-русского автоматического перевода.
И это все было задействовано на электротехнических текстах, на текстах, посвященных инженерии, электронике и механике. То есть тех текстов, в которых не такой богатый грамматический ряд, и скорее больше вариативности лексики, и причем узконаправленной лексики.
И в дальнейшем эти задачи модернизировались, и сейчас мы видим более продвинутый нейросетевой машинный перевод. Также можно выделить суммаризацию текстов, либо ее отдельную подзадачу, это задача симплификации. Но это используется обычно в реферировании работ, в написании автоматических аннотаций, Ну или в тех же поисковых системах, когда мы можем видеть в начале перед всеми ссылками сайтов такой некий драфт, некое сокращение от общей информации после того, как мы ввели поисковый запрос.
И это тоже является вариантом суммаризации текстов. Симплификация используется, как и в бизнесе, в маркетинге Для того, чтобы сделать тексты проще для определенной целевой аудитории Для того, чтобы повысить конверсию и удовлетворенность клиента тем или иным продуктом Ну и также может использоваться в науке для адаптации текстов под определенный уровень языка Допустим, если мы говорим про CEFR-уровни владения тем или иным иностранным языком"""

# %%
text_shopot_without_noise = """На данном этапе в Data Science NLP является одним из самых популярных направлений, наряду с компьютерным зрением и рекомендательными системами. И сегодня можно рассказать немножко о методах, которые включаются в NLP. Что такое в принципе NLP? NLP это Nature Language Processing, это автоматическая обработка текста с помощью компьютерных либо математических методов.
Ну и самое основное, что это методы, которые помогают понять значение языка и сделать определенные манипуляции с текстом либо с языком. Ну и от этого выходят основные задачи. Мы можем с помощью данных методов классифицировать тексты, то есть определять их на разные группы. Допустим, в контексте сентимент-анализа, когда нам нужно определить, положительные ли это тексты, либо негативные.
Также можно выделить эмоции текстов, допустим, грусть, радость, печаль, удивление и так далее. Либо разбить тексты по топикам или, как их называют в диалоговых системах, интенты для построения флоу диалога и ведения его, или в целом построения архитектуры FAQ в чат-ботах или голосовых ассистентах.
Кластеризация — это задача определения групп без меток, то есть у нас есть неразмеченные данные, и задача кластеризации будет относиться к задаче unsupervised learning, то есть это обучение без учителя, так как мы имеем дело с неразмеченными данными в отличие от классификации обучения с учителем.
Также есть классические задачи машинного перевода, и на самом деле в NLP они являются одними из самых, наверное, старых, потому что применялись еще в прошлом веке в контексте электротехнического автоматического перевода, либо там французско-русского автоматического перевода.
И это все было задействовано на электротехнических текстах, на текстах, посвященных инженерии, электронике и механике. То есть тех текстов, в которых нет такой богатый грамматический ряд, и скорее больше вариативности лексики, причем узконаправленной лексики.
И в дальнейшем эти задачи модернизировались, и сейчас мы видим более продвинутый нейросетевой машинный перевод. Также можно выделить суммаризацию текстов, либо ее отдельно под задачу, это задача симплификации. Но это используется обычно в реферировании работ, в написании автоматических аннотаций, Ну или в тех же поисковых системах, когда мы можем видеть в начале перед всеми ссылками сайтов такой некий драфт, некое сокращение от общей информации после того, как мы ввели поисковый запрос.
И это тоже является вариантом суммаризации текстов. Симплификация используется, как и в бизнесе, в маркетинге Для того, чтобы сделать тексты проще для определенной целевой аудитории Для того, чтобы повысить конверсию и удовлетворенность клиента тем или иным продуктом Ну и также может использоваться в науке для адаптации текстов под определенный уровень языка Допустим, если мы говорим про CFR-уровни владения тем или иным иностранным языком"""

# %%
text_shopot_with_noise = """На данном этапе в Data Science NLP является одним из самых популярных направлений наряду с компьютерным зрением и рекомендательными системами. И сегодня можно рассказать немножко о методах, которые включаются в NLP. Что такое в принципе NLP? NLP это Natural Language Processing, это автоматическая обработка текста с помощью компьютерных либо математических методов.
Ну и самое главное, что эти методы, которые помогают понять значение языка и сделать определенные манипуляции с текстом либо с языком. Ну и от этого выходят основные задачи. Мы можем с помощью данных методов классифицировать тексты, то есть определять их на разные группы. Допустим, в контексте сентимент-анализа, когда нам нужно определить, положительные ли это тексты, либо негативные.
Также можно выделить эмоции текстов, грусть, радость, печаль, удивление и так далее. Можно разбить текст по топикам, или как их называют в диалоговых системах, интенты для построения флоу диалога и ведения его, или в целом построения архитектуры FIQ в чат-ботах или голосовых ассистентах.
Кластеризация – это задача определения групп без меток, то есть у нас есть неразмеченные данные, и задача кластеризации будет относиться к задаче unsupervised learning, то есть это обучение без учителя, так как мы имеем дело с неразмеченными данными, в отличие от классификации обучения с учителем.
Также есть классические задачи машинного перевода. На самом деле в НУПе они являются одними из самых, наверное, старых, потому что применялись еще в прошлом веке в контексте электротехнического автоматического перевода, либо там французско-русского автоматического перевода.
И это все было задействовано на электротехнических текстах, на текстах, посвященных инженерии, электронике и механике То есть тех текстов, в которых не такой богатый грамматический ряд, а скорее больше вариативности лексики, и причем узконаправленной лексики И в дальнейшем эти тексты модернизировались, и сейчас мы видим более продвинутый не ростевой машинный перевод Также можно выделить суммаризацию текстов Либо ее отдельную подзадачу, это задача симплификации.
Это используется обычно в авторе реферирования работ, в написании автоматических аннотаций. Ну или в тех же поисковых системах, когда мы можем видеть вначале перед всеми ссылками сайтов такой некий драфт, некое сокращение от общей информации после того, как мы ввели поисковый запрос. И это тоже является вариантом суммаризации текстов Симплификация используется как и в бизнесе, в маркетинге Для того, чтобы сделать тексты проще для определенной целевой аудитории Для того, чтобы повысить конверсию и удовлетворенность клиента тем или иным продуктам Ну и также может использоваться в науке для адаптации текстов под определенный уровень языка Допустим, если мы говорим про CFR, уровень владения тем или иным иностранным языком."""

# %%
text_nexara_without_noise = """На данном этапе в Data Science NLP является одним из самых популярных направлений наряду с компьютерным зрением и рекомендательными системами. И сегодня можно рассказать немножко о методах, которые включаются NLP.
Что такое, в принципе, NLP? NLP — это Nature Language Processing, это автоматическая обработка текста с помощью компьютерных либо математических методов.
Ну и самое основное, что это методики, методы, которые помогают понять значение языка и сделать определенные манипуляции с текстом либо с языком.
Ну и от этого выходят основные задачи. Мы можем с помощью данных методов классифицировать тексты, то есть определять их на разные группы.
Допустим, в контексте сентимент-анализа, когда нам нужно определить положительные ли это тексты, либо негативные.
Также можно выделить эмоции текстов. допустим, грусть, радость, печаль, удивление и так далее.
Либо разбить тексты по топикам или как их называют в диалоговых системах интенты для построения флоу-диалога и введения его или в целом построения архитектуры FIQ в чат-ботах или голосовых ассистентах.
Квастеризация — это задача определения групп без меток. То есть у нас есть... неразмеченные данные, и задача кластеризации, она будет относиться к задаче Unsupervised Learning, то есть это обучение без учителя, так как мы имеем дело с неразмеченными данными в отличие от классификации обучения с учителем.
Также есть классические задачи машинного перевода, и на самом деле в NLP они являются одними из самых, наверное, старых, потому что применялись еще в прошлом веке в контексте электротехнического автоматического перевода, либо там французско-русского автоматического перевода, и это все было задействовано на электротехнических текстах, на текстах, посвященных инженерии, электронике и механике, то есть тех текстов, в которых нет такой богатый грамматический ряд, и скорее больше вариативности лексики, причем узконаправленной лексики.
И в дальнейшем эти задачи модернизировались, и сейчас мы видим более продвинутый нейросетевой машинный перевод. Также можно выделить суммаризацию текстов, либо ее отдельно под задачу, это задача симплификации, но это используется обычно в реферировании работ, в написании автоматически аннотации, ну или в тех же поисковых системах, когда мы можем видеть в начале, перед всеми ссылками сайтов, такой некий драфт, некое сокращение от общей информации после того, как мы ввели поисковый запрос, и это тоже является вариантом суммаризации текстов.
Симплификация используется как и в бизнесе, в маркетинге, для того, чтобы сделать тексты проще для определенной целевой аудитории, для того, чтобы повысить конверсию и удовлетворенность клиента тем или иным продуктам, ну и также может использоваться в науке для адаптации текстов под определенный уровень языка, допустим, если мы говорим про CFR уровни владения тем или иным иностранным языком."""

# %%
text_nexara_with_noise = """На данном этапе в Data Science NLP является одним из самых популярных направлений на ряду с компьютерным зрением и рекомендательными системами.
И сегодня можно рассказать немножко о методах, которые включаются NLP. Что такое, в принципе, NLP?
NLP – это Natural Language Processing, это автоматическая обработка текста с помощью компьютерных либо математических методов. Ну и самое главное, что эти методы, которые помогают понять значение языка и сделать определенные манипуляции с текстом, либо с языком.
Ну и от этого выходят основные задачи. Мы можем с помощью данных методов классифицировать тексты, то есть определять их на разные группы. Допустим, в контексте сентимент-анализа, когда нам нужно определить положительные ли это тексты, либо негативные.
Так Также можно выделить эмоции текстов, грусть, радость, печаль, удивление и так далее. Можно разбить текст по топикам, или как их называют в диалоговых системах, интенты для построения флоу-диалога и введения его, ну или в целом построения хитиктуры FIQ в чат-ботах или голосовых ассистентах. Кластеризация – это задача определения групп, пластеризация, без меток, то есть у нас есть неразмеченные данные и задача кластеризации будет относиться к задаче Unsupervised Learning, то есть это обучение без учителя, так как мы имеем дело с неразмеченными данными в отличие от классификации обучения с учителем.
Также есть классические задачи машинного перевода. На самом деле в NLP они являются одними из самых, наверное, старых, потому что при мне еще в прошлом веке в контексте электротехнического автоматического перевода, либо там французско-русского автоматического перевода.
И это все было задействовано на электротехнических текстах, на текстах, посвященных инженерии, электронике и механике. То есть тех текстов, в которых не такой богатый драматический ряд, а скорее больше вариативности лексики, и причем узконаправленной лексики. и в дальнейшем эти тексты модернизировались и сейчас мы видим более продвинутый не ростевой машинный перевод также можно выделить суммаризацию текстов либо ее отдельную подзадачу, это задача симплификации ну это используется обычно в авторе реферирования работ в написании автоматических аннотаций, ну или в тех же поисковых системах, когда мы можем видеть вначале перед всеми ссылками сайтов такой некий драфт, некое сокращение от общей информации после того, как мы ввели поисковый запрос. И это тоже является вариантом суммализации текстов.
Симплификация используется как и в бизнесе, в маркетинге, для того, чтобы сделать тексты проще для определенной целевой аудитории, для того, чтобы повысить конверсию и удовлетворенность клиентов. тем или иным продуктом.
Ну и также может использоваться в науке для адаптации текстов под определенный уровень языка, допустим, если мы говорим про SFR, уровень владения тем или иным иностранным языком."""

# %%
cer_shopot_without_noise = round(cer(text_shopot_without_noise, target_text), 4)
cer_shopot_with_noise = round(cer(text_shopot_with_noise, target_text), 4)

cer_nexara_without_noise = round(cer(text_nexara_without_noise, target_text), 4)
cer_nexara_with_noise = round(cer(text_nexara_with_noise, target_text), 4)

cer_whole_without_noise = [cer_shopot_without_noise, cer_nexara_without_noise]
cer_whole_with_noise = [cer_shopot_with_noise, cer_nexara_with_noise]

df_cer = pd.DataFrame(cer_whole_without_noise, columns=["CER Without Noise"], index=["SHOPOT", "NEXARA"])
df_cer["CER With Noise"] = cer_whole_with_noise
df_cer
# Out:
#         CER Without Noise  CER With Noise
# SHOPOT             0.0043          0.0274
# NEXARA             0.0274          0.0478

# %%
wer_shopot_without_noise = round(wer(text_shopot_without_noise, target_text), 4)
wer_shopot_with_noise = round(wer(text_shopot_with_noise, target_text), 4)

wer_nexara_without_noise = round(wer(text_nexara_without_noise, target_text), 4)
wer_nexara_with_noise = round(wer(text_nexara_with_noise, target_text), 4)

wer_whole_without_noise = [wer_shopot_without_noise, wer_nexara_without_noise]
wer_whole_with_noise = [wer_shopot_with_noise, wer_nexara_with_noise]

df_wer = pd.DataFrame(wer_whole_without_noise, columns=["WER Without Noise"], index=["SHOPOT", "NEXARA"])
df_wer["WER With Noise"] = wer_whole_with_noise
df_wer
# Out:
#         WER Without Noise  WER With Noise
# SHOPOT             0.0228          0.1091
# NEXARA             0.1628          0.1926

# %% [markdown]
# В ходе эксперимента была проанализирована одна и та же запись в двух вариациях: с шумом и без шума с двумя моделями: Nexara и "Шопот". В результате эксперимента обе модели на метриках CER и WER показали результаты хуже с шумом, чем без него. В основном большая часть ошибок была связана либо с распознаванием коротких слов (служебных частей речи), в частности вставок предлогов, а также транскрибации аббревиатур и англицизмов, например, НУПе (NLP), SFR или CFR (CEFR).
#
# Однако в целом, несмотря на шум, Nexara и "Шопот" не распознавали фоновые звуки как самостоятельные слова и не выдали артефакты, поэтому основная задача распознавания с шумом может считаться успешно выполнена.
